# %%
from selenium.webdriver import Chrome, ChromeOptions
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
from selenium import webdriver
# Initialize lists to store data
list1 = []
list2 = []

# Loop through each origin port
for i in range(10, 15):
    # Setup Chrome driver
    options = ChromeOptions()  # 팝업 차단 옵션 추가
    #options.add_argument('--headless')  # Optional: run in headless mode
    driver = Chrome(service=Service(ChromeDriverManager().install()), options=options)
    driver.get('https://www.tradlinx.com/container-freight-rate-tariff')
    ele=driver.find_element(by=By.CSS_SELECTOR,value='#ch-shadow-root-wrapper > div.ModalLayer__ModalLayerWrapper-ch-front__sc-10u1w92-0.jImPdL > div > article > div > div > div.PCFullscreenPopupContentstyled__PreviewSection-ch-front__sc-1he3s01-2.kzNqao > div > button')
    time.sleep(3)
    ele.send_keys(Keys.ENTER)
    # Navigate to the website
    ele=driver.find_element(By.CSS_SELECTOR,'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-title-area')
    time.sleep(3)
    ele.click()
    # Select the origin.find port
    ele = driver.find_element(By.CSS_SELECTOR, 'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(1) > div > span')
    ele.click()
    time.sleep(3)
    
    ele = driver.find_element(By.CSS_SELECTOR, f'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(1) > div > div > ul > li:nth-child({i})')
    time.sleep(3)
    ele.click()
    
    # Select the destination country
    ele = driver.find_element(By.CSS_SELECTOR, 'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > i')
    time.sleep(3)
    ele.click()
    
    ele = driver.find_element(By.CSS_SELECTOR, 'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(1)')
    time.sleep(3)
    ele.click()
    
    # Loop through each destination port within the selected country
    for j in range(1, 10):
        # Select the specific destination port
        ele = driver.find_element(By.CSS_SELECTOR, f'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(1) > ul > li:nth-child({j})')
        ele.click()
        
        # Open the port selection menu
        ele = driver.find_element(By.CSS_SELECTOR, 'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(2)')
        time.sleep(3)
        ele.click()
        
        # Select the specific port
        ele = driver.find_element(By.CSS_SELECTOR, f'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(2) > ul > li:nth-child({j})')
        time.sleep(3)
        ele.click()
        
        # Extract and store the necessary information
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        # Modify these selectors to match the actual elements containing the data you need
        rate_info = soup.select('your_rate_info_selector_here')
        tariff_info = soup.select('your_tariff_info_selector_here')
        
        # Append the extracted data to your lists
        list1.append(rate_info)
        list2.append(tariff_info)
    
    # Close the driver
    driver.quit()

# %%
driver = Chrome(service=Service(ChromeDriverManager().install()), options=ChromeOptions())
driver.get('https://www.tradlinx.com/container-freight-rate-tariff')
time.sleep(3)
ac = ActionChains(driver)
ac.move_by_offset(0, 350)
ac.click()
ac.perform()

# %%
# !pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#     --------------------------------------- 0.1/9.5 MB 7.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/9.5 MB 8.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/9.5 MB 12.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.6/9.5 MB 16.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.6/9.5 MB 17.6 MB/s eta 0:00:01
#    --------------------- ------------------ 5.1/9.5 MB 19.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.4/9.5 MB 21.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.5 MB 18.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 16.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 15.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.5 MB 14.7 MB/s eta 0:00:01
# ...

# %%
# !pip install webdriver_manager

# %%
from selenium.webdriver import Chrome, ChromeOptions
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

# %%
yes = 0
no = 0

driver = Chrome(service=Service(ChromeDriverManager().install()), options=ChromeOptions())
driver.get('https://www.tradlinx.com/container-freight-rate-tariff')
time.sleep(5)
ac = ActionChains(driver)
ac.move_by_offset(0, 350)
ac.click()
ac.perform()
time.sleep(3)

for i in range(10, 13):
    # 출발항
    ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(1) > div')
    ele.click()
    time.sleep(3)
    
    # 출발항 선택
    ele=driver.find_element(by=By.CSS_SELECTOR,value=f'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(1) > div > div > ul > li:nth-child({i}) > span')
    ele.click()
    time.sleep(3)
    
    for j in range(1, 139): # 항구의 갯수입니다. 국명 뒤 숫자 +1 을 넣어주세요 ##########################################################
        # 도착항
        ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > i')
        ele.click()
        time.sleep(3)
######################################################################################################################################        
        # 도착항 국가
        ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(1) > span')
        ele.click()
        time.sleep(10)
    
##### 국가 선택 (여기다가 css 선택자를 붙여넣으세요) ####################################################################################
        ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(1) > ul > li:nth-child(31)')
        ele.click()
        time.sleep(10)
######################################################################################################################################
        
        # 항구 
        ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(2) > span')
        ele.click()
        time.sleep(3)
        
        # 항구 선택
        ele=driver.find_element(by=By.CSS_SELECTOR,value=f'body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.route-input-inner > div:nth-child(2) > port-selector > div > div > ul > li:nth-child(2) > ul > li:nth-child({j})')
        ele.click()
        time.sleep(3)
        
        # 조회
        ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div.container-freight-rate-tariff-info-area > div.container-freight-rate-tariff-input-area > div > div.btn-area > button')
        ele.click()
        time.sleep(3)
        try:
            # 저장
            ele=driver.find_element(by=By.CSS_SELECTOR,value='body > application > div > container-freight-rate-tariff > div > div > div > div > div:nth-child(3) > div.result-top > div.excel-down-btn')
            ele.click()
            time.sleep(3)
            yes+=1
        except:
            no+=1
            continue

driver.quit()
print(f'출발항 수: {i}, 도착항 수:{j}, 총 시도: {yes+no}, 다운로드 파일 갯수: {yes}')
# Out:
# 출발항 수: 12, 도착항 수:138, 총 시도: 414, 다운로드 파일 갯수: 39
